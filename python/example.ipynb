# %%
import numpy as np
import flagstats as fs

# %%
fs.flagstats(np.random.randint(0,65536,100000000,dtype="uint16"))
# Out:
# {'passed': array([ 6249874,  3122995, 24998954,  3124708,  3124318,  3124066,
#          3125984,  3125043, 25006242, 49999326, 24996794, 12498458,
#          3907670,  3906179,  3904888,  3126496], dtype=uint32),
#  'failed': array([ 6247053,  3123240, 25005857,  3125071,  3125324,  3125066,
#          3122382,  3123090, 25005812, 50000674, 25002744, 12499209,
#          3904824,  3906023,  3902914,  3123930], dtype=uint32)}
